# %% [markdown]
# # Zadanie 2
#
# ### Sprawdzenie poprawnosci jednej iteracji forward/backward propagacji

# %%
from utils import *

# %%
## Zainicjalizowanie sieci neuronowej
y_train = [[0.25, 0.75]]
x_train = [[0.5, 0.25]]
network = (
    NeuralNetwork(
        hidden_layer=[
            Sigmoid(weights=[0.1, 0.25], bias=1), Sigmoid(weights=[0.2, 0.4], bias=0.5)
        ],
        output_layer=[
            Softmax(weights=[0.25, 0.5], bias=1.5),Softmax(weights=[1, 0.01], bias=0.1)],
        learnign_rate=0.001))

network.train(x_train, y_train, 1, True)
# Out:
# -----
# output perceptron 0
# 	error: 0.5118712051582853
# -----
# output perceptron 1
# 	error: -0.5118712051582853
# -----
# hidden perceptron 0
#
# 	output perceptron 0
# 	output error: 0.5118712051582853
# 	output der: 1
# 	output old weight: 0.25
#
# 	output perceptron 1
# 	output error: -0.5118712051582853
# 	output der: 1
# 	output old weight: 1
#
# SUMA: -0.383903403868714
# hidden der: 0.18619581908007005
#
# input index 0
# 	hidden error: -0.03574060436548107
# input index 1
# 	hidden error: -0.017870302182740536
# ------
# -----
# hidden perceptron 1
#
# 	output perceptron 0
# 	output error: 0.5118712051582853
# 	output der: 1
# 	output old weight: 0.5
#
# 	output perceptron 1
# 	output error: -0.5118712051582853
# 	output der: 1
# 	output old weight: 0.01
#
# SUMA: 0.2508168905275598
# hidden der: 0.22171287329310904
#
# input index 0
# 	hidden error: 0.027804666734654232
# input index 1
# 	hidden error: 0.013902333367327116
# ------

# %%
## Zainicjalizowanie sieci neuronowej
y_train = [[0, 1]]
x_train = [[0.5, 0.25]]
network = (
    NeuralNetwork(
        hidden_layer=[
            Sigmoid(weights=[0.1, 0.25], bias=1), Sigmoid(weights=[0.2, 0.4], bias=0.5)
        ],
        output_layer=[
            Softmax(weights=[0.25, 0.5], bias=1.5),Softmax(weights=[1, 0.01], bias=0.1)],
        learnign_rate=0.001))

network.train(x_train, y_train, 1, True)
# Out:
# -----
# output perceptron 0
# 	error: 0.7618712051582853
# -----
# output perceptron 1
# 	error: -0.7618712051582853
# -----
# hidden perceptron 0
#
# 	output perceptron 0
# 	output error: 0.7618712051582853
# 	output der: 1
# 	output old weight: 0.25
#
# 	output perceptron 1
# 	output error: -0.7618712051582853
# 	output der: 1
# 	output old weight: 1
#
# SUMA: -0.571403403868714
# hidden der: 0.18619581908007005
#
# input index 0
# 	hidden error: -0.053196462404237636
# input index 1
# 	hidden error: -0.026598231202118818
# ------
# -----
# hidden perceptron 1
#
# 	output perceptron 0
# 	output error: 0.7618712051582853
# 	output der: 1
# 	output old weight: 0.5
#
# 	output perceptron 1
# 	output error: -0.7618712051582853
# 	output der: 1
# 	output old weight: 0.01
#
# SUMA: 0.3733168905275598
# hidden der: 0.22171287329310904
#
# input index 0
# 	hidden error: 0.04138458022385716
# input index 1
# 	hidden error: 0.02069229011192858
# ------

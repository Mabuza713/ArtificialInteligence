# %% [markdown]
# # Zadanie 1
# Implementacja modelów perceptronu znajduje się w pliku utils.py

# %%
import random
from utils import *

# %%
# Tablica trzymająca wszystkie perceptrony zostanie wykorzystana do resetowania wag
perceptron_array = []

# %% [markdown]
# ## Perceptron Unipolarny z jednym wejściem

# %%
#w1 = float(random.randrange(-10, 10))
#b = float(random.randrange(-10, 10))

# Przykład w którym przyjęte parametry odrazu dobrze klasyfikują
#w1 = -9
#b = 6

# Przykład poza
w1 = 8
b = 6

uni_one = UnipolarPerceptron([w1], b, 0.01, "uni_one")
perceptron_array.append(uni_one)

# %% [markdown]
# ## Perceptron Unipolarny z dwoma wejściami

# %%
#w1 = float(random.randrange(-10, 10))
#w2 = float(random.randrange(-10, 10))
#b = float(random.randrange(-10, 10))

w1 = 9
w2 = -8
b = 9

uni_two = UnipolarPerceptron([w1, w2], b, 0.01, "uni_two_or")
perceptron_array.append(uni_two)

# %% [markdown]
# ## Perceptron Bipolarny z jednym wejściem

# %%
#w1 = float(random.randrange(-10, 10))
#b = float(random.randrange(-10, 10))

# Przykład w którym przyjęte parametry odrazu dobrze klasyfikują
#w1 = -9
#b = 6

# Przykład poza
w1 = 8
b = 6

bi_one = BipolarPerceptron([w1], b, 0.01,"bi_one")
perceptron_array.append(bi_one)

# %% [markdown]
# ## Perceptron Bipolarny z dwoma wejściami

# %%
w1 = float(random.randrange(-10, 10))
w2 = float(random.randrange(-10, 10))
b = float(random.randrange(-10, 10))
bi_two = BipolarPerceptron([w1, w2], b, 0.01, "bi_two_or")
perceptron_array.append(bi_two)

# %% [markdown]
# # Zadanie 2
# W celu przeprowadzenia uczenia perceptronów pierwszym krokiem będzie przygotowanie zbioru uczącego tzn. stworzenie takich wejść i wyjść odpowiadających operacją logicznym

# %%
or_two_X = [[1, 1], [1, 0], [0, 1], [0, 0]]
or_two_Y = [1, 1, 1, 0]

and_two_X = [[1, 1], [1, 0], [0, 1], [0, 0]]
and_two_Y = [1, 0, 0, 0]

not_one_X = [[1], [0]]
not_one_Y = [0, 1]

xor_two_X = [[1, 1], [1, 0], [0, 1], [0, 0]]
xor_two_Y = [0, 1, 1, 0]

# %% [markdown]
# Następnie przy użyciu funckji tune_weights wyucze perceptrony

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Zadanie 2
# ## Operacje dla OR

# %% [markdown]
# ### Unipolarny

# %%
# Dobrze widać
# Początkowe wartości wag: [6, 7]
# Początkowe wartości obciążenia: -9

# Ciekawy przykład
# Początkowe wartości wag: [9, -10]
# Początkowe wartości obciążenia: 1

# %%
uni_two.reset_weights()
uni_two.tune_weights(or_two_X, or_two_Y, 1_000_001)
# Out:
# False
# Iteracja:  0
# Wagi w iteracji [poprzedniej - teraźniejszej]: [9, -8] - [9.0, -8.0]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 9 - 8.99
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# -------------------------------------------
#
# False
# Iteracja:  10
# Wagi w iteracji [poprzedniej - teraźniejszej]: [9.0, -8.0] - [9.0, -8.0]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 8.900000000000002 - 8.890000000000002
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# -------------------------------------------
#
# False
# Iteracja:  20
# Wagi w iteracji [poprzedniej - teraźniejszej]: [9.0, -8.0] - [9.0, -8.0]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 8.800000000000004 - 8.790000000000004
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# -------------------------------------------
#
# False
# Iteracja:  30
# Wagi w iteracji [poprzedniej - teraźniejszej]: [9.0, -8.0] - [9.0, -8.0]
# ...

# %%
create_plot(or_two_X, or_two_Y, uni_two, "OR")

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ### Bipolarny

# %%
bi_two.reset_weights()
bi_two.tune_weights(or_two_X, or_two_Y, 1_000_000)
# Out:
# False
# Iteracja:  0
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-5.0, 4.0] - [-4.960000000000001, 4.039999999999999]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -5.0 - -4.940000000000001
# Początkowe wartości wag: [-5.0, 4.0]
# Początkowe wartości obciążenia: -5.0
# -------------------------------------------
#
# False
# Iteracja:  10
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-4.6000000000000085, 4.3999999999999915] - [-4.560000000000009, 4.419999999999991]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -4.400000000000013 - -4.360000000000014
# Początkowe wartości wag: [-5.0, 4.0]
# Początkowe wartości obciążenia: -5.0
# -------------------------------------------
#
# False
# Iteracja:  20
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-4.200000000000017, 4.599999999999987] - [-4.160000000000018, 4.619999999999987]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -4.000000000000021 - -3.9600000000000213
# ...

# %%
create_plot(or_two_X, or_two_Y, bi_two, "OR")

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Operacje dla AND

# %% [markdown]
# ### Unipolarny

# %%
uni_two.dir_name = "uni_two_and"
uni_two.reset_weights()
uni_two.tune_weights(and_two_X, and_two_Y, 1_000_001)
# Out:
# False
# Iteracja:  0
# Wagi w iteracji [poprzedniej - teraźniejszej]: [9, -8] - [8.99, -8.01]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 9 - 8.97
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# -------------------------------------------
#
# False
# Iteracja:  10
# Wagi w iteracji [poprzedniej - teraźniejszej]: [8.900000000000002, -8.099999999999998] - [8.890000000000002, -8.109999999999998]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 8.700000000000006 - 8.670000000000007
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# -------------------------------------------
#
# False
# Iteracja:  20
# Wagi w iteracji [poprzedniej - teraźniejszej]: [8.800000000000004, -8.199999999999996] - [8.790000000000004, -8.209999999999996]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 8.400000000000013 - 8.370000000000013
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# ...

# %%
create_plot(and_two_X, and_two_Y, uni_two, "AND")

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ### Bipolarny

# %%
bi_two.dir_name = "bi_two_and"
bi_two.reset_weights()
bi_two.tune_weights(and_two_X, and_two_Y, 1_000_001)
# Out:
# False
# Iteracja:  0
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-5.0, 4.0] - [-4.98, 4.02]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -5.0 - -4.98
# Początkowe wartości wag: [-5.0, 4.0]
# Początkowe wartości obciążenia: -5.0
# -------------------------------------------
#
# False
# Iteracja:  10
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-4.800000000000004, 4.199999999999996] - [-4.780000000000005, 4.219999999999995]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -4.800000000000004 - -4.780000000000005
# Początkowe wartości wag: [-5.0, 4.0]
# Początkowe wartości obciążenia: -5.0
# -------------------------------------------
#
# False
# Iteracja:  20
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-4.6000000000000085, 4.3999999999999915] - [-4.580000000000009, 4.419999999999991]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -4.6000000000000085 - -4.580000000000009
# Początkowe wartości wag: [-5.0, 4.0]
# ...

# %%
create_plot(and_two_X, and_two_Y, uni_two, "AND")

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Operacje dla NOT

# %% [markdown]
# ### Unipolarny

# %%
uni_one.tune_weights(not_one_X, not_one_Y, 1_000_001)
# Out:
# False
# Iteracja:  0
# Wagi w iteracji [poprzedniej - teraźniejszej]: [8] - [7.99]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 6 - 5.99
# Początkowe wartości wag: [8]
# Początkowe wartości obciążenia: 6
# -------------------------------------------
#
# False
# Iteracja:  10
# Wagi w iteracji [poprzedniej - teraźniejszej]: [7.900000000000002] - [7.890000000000002]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 5.900000000000002 - 5.890000000000002
# Początkowe wartości wag: [8]
# Początkowe wartości obciążenia: 6
# -------------------------------------------
#
# False
# Iteracja:  20
# Wagi w iteracji [poprzedniej - teraźniejszej]: [7.800000000000004] - [7.7900000000000045]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 5.800000000000004 - 5.7900000000000045
# Początkowe wartości wag: [8]
# Początkowe wartości obciążenia: 6
# -------------------------------------------
#
# False
# Iteracja:  30
# ...

# %%
create_plot(not_one_X, not_one_Y, uni_one, "NOT")

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ### Bipolarny

# %%
bi_one.tune_weights(not_one_X, not_one_Y, 1_000_001)
# Out:
# False
# Iteracja:  0
# Wagi w iteracji [poprzedniej - teraźniejszej]: [8] - [7.98]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 6 - 5.98
# Początkowe wartości wag: [8]
# Początkowe wartości obciążenia: 6
# -------------------------------------------
#
# False
# Iteracja:  10
# Wagi w iteracji [poprzedniej - teraźniejszej]: [7.800000000000004] - [7.780000000000005]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 5.800000000000004 - 5.780000000000005
# Początkowe wartości wag: [8]
# Początkowe wartości obciążenia: 6
# -------------------------------------------
#
# False
# Iteracja:  20
# Wagi w iteracji [poprzedniej - teraźniejszej]: [7.6000000000000085] - [7.580000000000009]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 5.6000000000000085 - 5.580000000000009
# Początkowe wartości wag: [8]
# Początkowe wartości obciążenia: 6
# -------------------------------------------
#
# False
# Iteracja:  30
# ...

# %%
create_plot(not_one_X, not_one_Y, uni_one, "NOT")

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Operacje dla XOR

# %% [markdown]
# ### Unipolarny

# %%
uni_two.dir_name = "uni_two_xor"
uni_two.reset_weights()
uni_two.tune_weights(xor_two_X, xor_two_Y, 100)
# Out:
# False
# Iteracja:  0
# Wagi w iteracji [poprzedniej - teraźniejszej]: [9, -8] - [8.99, -8.01]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 9 - 8.98
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# -------------------------------------------
#
# False
# Iteracja:  10
# Wagi w iteracji [poprzedniej - teraźniejszej]: [8.900000000000002, -8.099999999999998] - [8.890000000000002, -8.109999999999998]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 8.800000000000004 - 8.780000000000005
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# -------------------------------------------
#
# False
# Iteracja:  20
# Wagi w iteracji [poprzedniej - teraźniejszej]: [8.800000000000004, -8.199999999999996] - [8.790000000000004, -8.209999999999996]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: 8.600000000000009 - 8.580000000000009
# Początkowe wartości wag: [9, -8]
# Początkowe wartości obciążenia: 9
# ...

# %%
create_plot(xor_two_X, xor_two_Y, uni_two, "XOR")

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ### Bipolarny

# %%
bi_two.dir_name = "bi_two_xor"
bi_two.reset_weights()
bi_two.tune_weights(xor_two_X, xor_two_Y, 100)
# Out:
# False
# Iteracja:  0
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-5.0, 4.0] - [-4.98, 4.02]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -5.0 - -4.960000000000001
# Początkowe wartości wag: [-5.0, 4.0]
# Początkowe wartości obciążenia: -5.0
# -------------------------------------------
#
# False
# Iteracja:  10
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-4.800000000000004, 4.199999999999996] - [-4.780000000000005, 4.219999999999995]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -4.6000000000000085 - -4.560000000000009
# Początkowe wartości wag: [-5.0, 4.0]
# Początkowe wartości obciążenia: -5.0
# -------------------------------------------
#
# False
# Iteracja:  20
# Wagi w iteracji [poprzedniej - teraźniejszej]: [-4.6000000000000085, 4.339999999999993] - [-4.580000000000009, 4.339999999999993]
# obciążenie w iteracji [poprzedniej - teraźniejszej]: -4.260000000000016 - -4.240000000000016
# Początkowe wartości wag: [-5.0, 4.0]
# ...

# %%
create_plot(xor_two_X, xor_two_Y, bi_two, "XOR")

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Zadanie 4

# %%
from utils import *
import random

xor_two_X = [[1, 1], [1, 0], [0, 1], [0, 0]]
xor_two_Y = [[0], [1], [1], [0]]
learning_rate = 0.01

network = NeuralNetwork(hidden_layer=[Sigmoid(weights=[random.uniform(-1, 1), random.uniform(-1, 1),], bias=random.uniform(-1, 1), learning_rate=learning_rate),
                                      Sigmoid(weights=[random.uniform(-1, 1),random.uniform(-1, 1)], bias=random.uniform(-1, 1), learning_rate=learning_rate)],
                        output_layer=[Sigmoid(weights=[random.uniform(-1, 1),random.uniform(-1, 1)], bias=random.uniform(-1, 1), learning_rate=learning_rate)],
                        learnign_rate=0.25)

network.train(xor_two_X, xor_two_Y, 100_000)

create_plot_with_two(xor_two_X, [0, 1, 1, 0], [network.hidden_layer[0], network.hidden_layer[1]])

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(xor_two_X, xor_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")
# Out:
# C:\Users\uxbei\Desktop\ArtificialInteligence\utils.py:200: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# [np.float64(-6.749919225539961), np.float64(6.664253705931173)] -0.8827493205532164
# [np.float64(-6.35900927141319), np.float64(6.580833406182441)] 0.12961702763185823
# [np.float64(11.171401302124828), np.float64(-10.919666686234654)] 0.028286303102811106
# [np.float64(0.0063632199417020825)] - [0]
# [np.float64(0.9918680591608157)] - [1]
# [np.float64(0.9933129820937947)] - [1]
# [np.float64(0.007082887437198754)] - [0]

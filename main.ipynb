# %%
from utils import *

# %%
perceptron_bi = BipolarPerceptron([10,10], 1, 0.01)
#perceptron_bi = BipolarPerceptron([-0.5], 1, 0.01)

# %%
#X = [[1, 1], [1, 0], [0, 1], [0, 0], [0.5, 0.25], [0.25, 0.5],[0.45, 0.45]]
X = [[1], [1], [1], [0]]
Y = [1, 1, 1, 0]
#Y = [1, 1, 1, -1, -1, -1, 1]

perceptron_bi.tune_weights(X, Y, 10_000_00)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 Y = [1, 1, 1, 0]
#       4 #Y = [1, 1, 1, -1, -1, -1, 1]
# ----> 6 perceptron_bi.tune_weights(X, Y, 10_000_00)
#
# File ~/Documents/ArtificialInteligence/utils.py:27, in Perceptron.tune_weights(self, X, Y, amount_of_iterations)
#      25         if y_pred != y:
#      26             error = y - y_pred
# ---> 27             self.weights = [self.weights[index] + self.learning_rate * error * x[index] for index in range(len(self.weights))]
#      28             self.bias = self.bias +self.learning_rate * error
#      30 print(self.weights)
#
# IndexError: list index out of range

# %%
create_plot(X, Y, perceptron_bi)

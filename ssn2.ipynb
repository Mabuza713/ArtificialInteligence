# %% [markdown]
# # Zadanie 3

# %%
from utils import *
import random

two_X = [[1, 1], [1, 0], [0, 1], [0, 0]]
xor_two_Y = [[0], [1], [1], [0]]
or_two_Y = [[1], [1], [1], [0]]
and_two_Y = [[1], [0], [0], [0]]
nand_two_Y = [[0], [1], [1], [1]]
learning_rate = 0.01

network = NeuralNetwork(hidden_layer=[Sigmoid(weights=[random.uniform(-1, 1), random.uniform(-1, 1),], bias=random.uniform(-1, 1), learning_rate=learning_rate),
                                      Sigmoid(weights=[random.uniform(-1, 1),random.uniform(-1, 1)], bias=random.uniform(-1, 1), learning_rate=learning_rate)],
                        output_layer=[Sigmoid(weights=[random.uniform(-1, 1),random.uniform(-1, 1)], bias=random.uniform(-1, 1), learning_rate=learning_rate)],
                        learnign_rate=0.25)

network.reset_weights()
network.train(two_X, xor_two_Y, 100_000)

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(two_X, xor_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")

network.reset_weights()
network.train(two_X, or_two_Y, 100_000)

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(two_X, or_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")

network.reset_weights()
network.train(two_X, and_two_Y, 100_000)

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(two_X, and_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")

network.reset_weights()
network.train(two_X, nand_two_Y, 1_00_000)

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(two_X, xor_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")
# Out:
# [0.3450716751831624, -0.734326631424485] -0.969119305862097
# [0.2835092691052834, -0.5905480579918607] 0.48242188452254475
# [-0.9087691987021569, 0.009741885304679343] 0.19198110460489026
# [np.float64(0.007010892416314531)] - [0]
# [np.float64(0.9924630933852917)] - [1]
# [np.float64(0.9925680375911695)] - [1]
# [np.float64(0.006587650334678577)] - [0]
# [0.3450716751831624, -0.734326631424485] -0.969119305862097
# [0.2835092691052834, -0.5905480579918607] 0.48242188452254475
# [-0.9087691987021569, 0.009741885304679343] 0.19198110460489026
# [np.float64(0.9991409664574121)] - [1]
# [np.float64(0.9964301299032396)] - [1]
# [np.float64(0.9964200081519354)] - [1]
# [np.float64(0.005054203798621873)] - [0]
# [0.3450716751831624, -0.734326631424485] -0.969119305862097
# [0.2835092691052834, -0.5905480579918607] 0.48242188452254475
# [-0.9087691987021569, 0.009741885304679343] 0.19198110460489026
# [np.float64(0.9944944178888933)] - [1]
# [np.float64(0.003907150705852378)] - [0]
# [np.float64(0.003917661853232518)] - [0]
# [np.float64(0.00021610314824840345)] - [0]
# [0.3450716751831624, -0.734326631424485] -0.969119305862097
# [0.2835092691052834, -0.5905480579918607] 0.48242188452254475
# [-0.9087691987021569, 0.009741885304679343] 0.19198110460489026
# [np.float64(0.002215101396447826)] - [0]
# [np.float64(0.998796155002577)] - [1]
# [np.float64(0.9987974919511617)] - [1]
# [np.float64(0.9999475590812462)] - [0]

# %% [markdown]
# # Zadanie 4

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

y_encoded = one_hot_encode(y)

learning_rate = 0.05
n_inputs = 4 #4 wejscia
n_hidden = 4
n_outputs = 3 #3 wyjscia

network = NeuralNetwork(
    hidden_layer=[Sigmoid(weights=[random.uniform(-1,1) for _ in range(n_inputs)],
                          bias=random.uniform(-1,1), learning_rate=learning_rate)
                  for _ in range(n_hidden)],
    output_layer=[Sigmoid(weights=[random.uniform(-1,1) for _ in range(n_hidden)],
                          bias=random.uniform(-1,1), learning_rate=learning_rate)
                  for _ in range(n_outputs)],
    learnign_rate=learning_rate
)

network.train(X.tolist(), y_encoded.tolist(), 10_000)

for i in range(len(X)):
    input_sample = X[i].tolist()
    predicted = network.forward_propagation(input_sample)
    actual_class = y_encoded[i].tolist()
    input_sample_fmt = format_list(input_sample)
    predicted_fmt = format_list(predicted, 3)
    actual_class_fmt = format_list(actual_class)
    print(f"Wejście: {input_sample_fmt} -> Predykcja: {predicted_fmt} -> Rzeczywista: {actual_class_fmt}")
# Out:
# Wejście: [5.1, 3.5, 1.4, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.9, 3.0, 1.4, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.7, 3.2, 1.3, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.6, 3.1, 1.5, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.6, 1.4, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.9, 1.7, 0.4] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.6, 3.4, 1.4, 0.3] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.4, 1.5, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.4, 2.9, 1.4, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.9, 3.1, 1.5, 0.1] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.7, 1.5, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.4, 1.6, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.0, 1.4, 0.1] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.3, 3.0, 1.1, 0.1] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.8, 4.0, 1.2, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.7, 4.4, 1.5, 0.4] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.9, 1.3, 0.4] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.5, 1.4, 0.3] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.7, 3.8, 1.7, 0.3] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.8, 1.5, 0.3] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.4, 1.7, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.7, 1.5, 0.4] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.6, 3.6, 1.0, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.3, 1.7, 0.5] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.4, 1.9, 0.2] -> Predykcja: [0.991, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.0, 1.6, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.4, 1.6, 0.4] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.2, 3.5, 1.5, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.2, 3.4, 1.4, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.7, 3.2, 1.6, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.1, 1.6, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.4, 1.5, 0.4] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.2, 4.1, 1.5, 0.1] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.5, 4.2, 1.4, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.9, 3.1, 1.5, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.2, 1.2, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.5, 3.5, 1.3, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.9, 3.6, 1.4, 0.1] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.4, 3.0, 1.3, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.4, 1.5, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.5, 1.3, 0.3] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.5, 2.3, 1.3, 0.3] -> Predykcja: [0.997, 0.109, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.4, 3.2, 1.3, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.5, 1.6, 0.6] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.8, 1.9, 0.4] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.0, 1.4, 0.3] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.8, 1.6, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.6, 3.2, 1.4, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.3, 3.7, 1.5, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.3, 1.4, 0.2] -> Predykcja: [0.992, 0.007, 0.007] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [7.0, 3.2, 4.7, 1.4] -> Predykcja: [0.003, 0.984, 0.013] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.4, 3.2, 4.5, 1.5] -> Predykcja: [0.002, 0.966, 0.029] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.9, 3.1, 4.9, 1.5] -> Predykcja: [0.003, 0.987, 0.011] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.3, 4.0, 1.3] -> Predykcja: [0.014, 1.0, 0.0] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.5, 2.8, 4.6, 1.5] -> Predykcja: [0.006, 0.998, 0.001] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 2.8, 4.5, 1.3] -> Predykcja: [0.002, 0.969, 0.027] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.3, 3.3, 4.7, 1.6] -> Predykcja: [0.002, 0.965, 0.03] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [4.9, 2.4, 3.3, 1.0] -> Predykcja: [0.003, 0.98, 0.015] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.6, 2.9, 4.6, 1.3] -> Predykcja: [0.006, 0.998, 0.002] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.2, 2.7, 3.9, 1.4] -> Predykcja: [0.002, 0.966, 0.029] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.0, 2.0, 3.5, 1.0] -> Predykcja: [0.026, 1.0, 0.0] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.9, 3.0, 4.2, 1.5] -> Predykcja: [0.002, 0.966, 0.029] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.0, 2.2, 4.0, 1.0] -> Predykcja: [0.03, 1.0, 0.0] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.1, 2.9, 4.7, 1.4] -> Predykcja: [0.002, 0.971, 0.024] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 2.9, 3.6, 1.3] -> Predykcja: [0.002, 0.964, 0.028] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.7, 3.1, 4.4, 1.4] -> Predykcja: [0.003, 0.981, 0.016] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 3.0, 4.5, 1.5] -> Predykcja: [0.002, 0.964, 0.03] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.8, 2.7, 4.1, 1.0] -> Predykcja: [0.003, 0.991, 0.007] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.2, 2.2, 4.5, 1.5] -> Predykcja: [0.0, 0.993, 0.006] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 2.5, 3.9, 1.1] -> Predykcja: [0.006, 0.998, 0.001] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.9, 3.2, 4.8, 1.8] -> Predykcja: [0.0, 0.7, 0.286] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.1, 2.8, 4.0, 1.3] -> Predykcja: [0.003, 0.989, 0.009] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.3, 2.5, 4.9, 1.5] -> Predykcja: [0.0, 0.368, 0.635] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.1, 2.8, 4.7, 1.2] -> Predykcja: [0.003, 0.987, 0.011] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.4, 2.9, 4.3, 1.3] -> Predykcja: [0.004, 0.992, 0.007] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.6, 3.0, 4.4, 1.4] -> Predykcja: [0.003, 0.988, 0.01] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.8, 2.8, 4.8, 1.4] -> Predykcja: [0.018, 1.0, 0.0] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.7, 3.0, 5.0, 1.7] -> Predykcja: [0.001, 0.953, 0.041] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.0, 2.9, 4.5, 1.5] -> Predykcja: [0.002, 0.969, 0.027] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 2.6, 3.5, 1.0] -> Predykcja: [0.007, 0.998, 0.002] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.4, 3.8, 1.1] -> Predykcja: [0.01, 1.0, 0.0] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.4, 3.7, 1.0] -> Predykcja: [0.012, 1.0, 0.0] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.8, 2.7, 3.9, 1.2] -> Predykcja: [0.003, 0.987, 0.01] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.0, 2.7, 5.1, 1.6] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.4, 3.0, 4.5, 1.5] -> Predykcja: [0.002, 0.962, 0.032] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.0, 3.4, 4.5, 1.6] -> Predykcja: [0.002, 0.965, 0.03] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.7, 3.1, 4.7, 1.5] -> Predykcja: [0.002, 0.977, 0.019] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.3, 2.3, 4.4, 1.3] -> Predykcja: [0.029, 1.0, 0.0] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 3.0, 4.1, 1.3] -> Predykcja: [0.002, 0.965, 0.029] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.5, 4.0, 1.3] -> Predykcja: [0.004, 0.992, 0.006] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.6, 4.4, 1.2] -> Predykcja: [0.002, 0.979, 0.018] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.1, 3.0, 4.6, 1.4] -> Predykcja: [0.002, 0.967, 0.028] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.8, 2.6, 4.0, 1.2] -> Predykcja: [0.005, 0.997, 0.002] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.0, 2.3, 3.3, 1.0] -> Predykcja: [0.006, 0.997, 0.002] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 2.7, 4.2, 1.3] -> Predykcja: [0.002, 0.973, 0.023] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 3.0, 4.2, 1.2] -> Predykcja: [0.002, 0.965, 0.029] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 2.9, 4.2, 1.3] -> Predykcja: [0.002, 0.966, 0.028] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.2, 2.9, 4.3, 1.3] -> Predykcja: [0.003, 0.98, 0.017] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.1, 2.5, 3.0, 1.1] -> Predykcja: [0.004, 0.973, 0.016] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 2.8, 4.1, 1.3] -> Predykcja: [0.002, 0.97, 0.026] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.3, 3.3, 6.0, 2.5] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.8, 2.7, 5.1, 1.9] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.1, 3.0, 5.9, 2.1] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 2.9, 5.6, 1.8] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.5, 3.0, 5.8, 2.2] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.6, 3.0, 6.6, 2.1] -> Predykcja: [0.0, 0.012, 0.99] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [4.9, 2.5, 4.5, 1.7] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.3, 2.9, 6.3, 1.8] -> Predykcja: [0.0, 0.022, 0.981] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 2.5, 5.8, 1.8] -> Predykcja: [0.0, 0.086, 0.921] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.2, 3.6, 6.1, 2.5] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.5, 3.2, 5.1, 2.0] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 2.7, 5.3, 1.9] -> Predykcja: [0.0, 0.001, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.8, 3.0, 5.5, 2.1] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.7, 2.5, 5.0, 2.0] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.8, 2.8, 5.1, 2.4] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 3.2, 5.3, 2.3] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.5, 3.0, 5.5, 1.8] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.7, 3.8, 6.7, 2.2] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.7, 2.6, 6.9, 2.3] -> Predykcja: [0.0, 0.119, 0.888] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.0, 2.2, 5.0, 1.5] -> Predykcja: [0.0, 0.107, 0.901] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.9, 3.2, 5.7, 2.3] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.6, 2.8, 4.9, 2.0] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.7, 2.8, 6.7, 2.0] -> Predykcja: [0.0, 0.106, 0.901] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 2.7, 4.9, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 3.3, 5.7, 2.1] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.2, 3.2, 6.0, 1.8] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.2, 2.8, 4.8, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.1, 3.0, 4.9, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 2.8, 5.6, 2.1] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.2, 3.0, 5.8, 1.6] -> Predykcja: [0.0, 0.005, 0.996] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.4, 2.8, 6.1, 1.9] -> Predykcja: [0.0, 0.082, 0.925] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.9, 3.8, 6.4, 2.0] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 2.8, 5.6, 2.2] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 2.8, 5.1, 1.5] -> Predykcja: [0.0, 0.013, 0.989] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.1, 2.6, 5.6, 1.4] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.7, 3.0, 6.1, 2.3] -> Predykcja: [0.0, 0.021, 0.981] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 3.4, 5.6, 2.4] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 3.1, 5.5, 1.8] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.0, 3.0, 4.8, 1.8] -> Predykcja: [0.0, 0.014, 0.987] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.9, 3.1, 5.4, 2.1] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 3.1, 5.6, 2.4] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.9, 3.1, 5.1, 2.3] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.8, 2.7, 5.1, 1.9] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.8, 3.2, 5.9, 2.3] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 3.3, 5.7, 2.5] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 3.0, 5.2, 2.3] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 2.5, 5.0, 1.9] -> Predykcja: [0.0, 0.018, 0.984] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.5, 3.0, 5.2, 2.0] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.2, 3.4, 5.4, 2.3] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.9, 3.0, 5.1, 1.8] -> Predykcja: [0.0, 0.0, 1.0] -> Rzeczywista: [0.0, 0.0, 1.0]

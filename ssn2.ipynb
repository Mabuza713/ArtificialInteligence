# %% [markdown]
# # Zadanie 3

# %%
from utils import *
import random

two_X = [[1, 1], [1, 0], [0, 1], [0, 0]]
xor_two_Y = [[0], [1], [1], [0]]
or_two_Y = [[1], [1], [1], [0]]
and_two_Y = [[1], [0], [0], [0]]
nand_two_Y = [[0], [1], [1], [1]]
learning_rate = 0.01

network = NeuralNetwork(hidden_layer=[Sigmoid(weights=[random.uniform(-1, 1), random.uniform(-1, 1),], bias=random.uniform(-1, 1), learning_rate=learning_rate),
                                      Sigmoid(weights=[random.uniform(-1, 1),random.uniform(-1, 1)], bias=random.uniform(-1, 1), learning_rate=learning_rate)],
                        output_layer=[Sigmoid(weights=[random.uniform(-1, 1),random.uniform(-1, 1)], bias=random.uniform(-1, 1), learning_rate=learning_rate)],
                        learnign_rate=0.25)

network.reset_weights()
network.train(two_X, xor_two_Y, 100_000)

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(two_X, xor_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")

network.reset_weights()
network.train(two_X, or_two_Y, 100_000)

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(two_X, or_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")

network.reset_weights()
network.train(two_X, and_two_Y, 100_000)

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(two_X, and_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")

network.reset_weights()
network.train(two_X, nand_two_Y, 1_00_000)

print(network.hidden_layer[0].initial_weights, network.hidden_layer[0].initial_bias)
print(network.hidden_layer[1].initial_weights, network.hidden_layer[1].initial_bias)
print(network.output_layer[0].initial_weights, network.output_layer[0].initial_bias)
for x, y in zip(two_X, xor_two_Y):
    print(f"{network.forward_propagation(x)} - {y}")
# Out:
# [-0.09377378949658555, -0.5356178505702203] 0.6254886756325428
# [0.9296385439019907, -0.9778332371459784] -0.03522711093217579
# [0.41818662858262856, -0.34605109070856077] 0.41057026726748513
# [np.float64(0.006384802550420061)] - [0]
# [np.float64(0.9918396819689285)] - [1]
# [np.float64(0.9932907460179748)] - [1]
# [np.float64(0.007108283787435722)] - [0]
# [-0.09377378949658555, -0.5356178505702203] 0.6254886756325428
# [0.9296385439019907, -0.9778332371459784] -0.03522711093217579
# [0.41818662858262856, -0.34605109070856077] 0.41057026726748513
# [np.float64(0.9991285262010239)] - [1]
# [np.float64(0.9960789192955548)] - [1]
# [np.float64(0.9961777456590851)] - [1]
# [np.float64(0.0071384769149064045)] - [0]
# [-0.09377378949658555, -0.5356178505702203] 0.6254886756325428
# [0.9296385439019907, -0.9778332371459784] -0.03522711093217579
# [0.41818662858262856, -0.34605109070856077] 0.41057026726748513
# [np.float64(0.9935520183802904)] - [1]
# [np.float64(0.004719637893742492)] - [0]
# [np.float64(0.005301592420329144)] - [0]
# [np.float64(0.0009545600964510434)] - [0]
# [-0.09377378949658555, -0.5356178505702203] 0.6254886756325428
# [0.9296385439019907, -0.9778332371459784] -0.03522711093217579
# [0.41818662858262856, -0.34605109070856077] 0.41057026726748513
# [np.float64(0.00557507206656277)] - [0]
# [np.float64(0.9961595381847702)] - [1]
# [np.float64(0.99614831448444)] - [1]
# [np.float64(0.9998063088928306)] - [0]

# %% [markdown]
# # Zadanie 4

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

y_encoded = one_hot_encode(y)

learning_rate = 0.05
n_inputs = 4 #4 wejscia
n_hidden = 4
n_outputs = 3 #3 wyjscia

network = NeuralNetwork(
    hidden_layer=[Sigmoid(weights=[random.uniform(-1,1) for _ in range(n_inputs)],
                          bias=random.uniform(-1,1), learning_rate=learning_rate)
                  for _ in range(n_hidden)],
    output_layer=[Softmax(weights=[random.uniform(-1,1) for _ in range(n_hidden)],
                          bias=random.uniform(-1,1), learning_rate=learning_rate)
                  for _ in range(n_outputs)],
    learnign_rate=learning_rate
)

network.train(X.tolist(), y_encoded.tolist(), 1000)

for i in range(len(X)):
    input_sample = X[i].tolist()
    predicted = network.forward_propagation(input_sample)
    actual_class = y_encoded[i].tolist()
    input_sample_fmt = format_list(input_sample)
    predicted_fmt = format_list(predicted, 3)
    actual_class_fmt = format_list(actual_class)
    print(f"Wejście: {input_sample_fmt} -> Predykcja: {predicted_fmt} -> Rzeczywista: {actual_class_fmt}")
# Out:
# Wejście: [5.1, 3.5, 1.4, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.9, 3.0, 1.4, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.7, 3.2, 1.3, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.6, 3.1, 1.5, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.6, 1.4, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.9, 1.7, 0.4] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.6, 3.4, 1.4, 0.3] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.4, 1.5, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.4, 2.9, 1.4, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.9, 3.1, 1.5, 0.1] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.7, 1.5, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.4, 1.6, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.0, 1.4, 0.1] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.3, 3.0, 1.1, 0.1] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.8, 4.0, 1.2, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.7, 4.4, 1.5, 0.4] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.9, 1.3, 0.4] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.5, 1.4, 0.3] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.7, 3.8, 1.7, 0.3] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.8, 1.5, 0.3] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.4, 1.7, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.7, 1.5, 0.4] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.6, 3.6, 1.0, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.3, 1.7, 0.5] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.4, 1.9, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.0, 1.6, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.4, 1.6, 0.4] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.2, 3.5, 1.5, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.2, 3.4, 1.4, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.7, 3.2, 1.6, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.1, 1.6, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.4, 3.4, 1.5, 0.4] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.2, 4.1, 1.5, 0.1] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.5, 4.2, 1.4, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.9, 3.1, 1.5, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.2, 1.2, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.5, 3.5, 1.3, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.9, 3.6, 1.4, 0.1] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.4, 3.0, 1.3, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.4, 1.5, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.5, 1.3, 0.3] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.5, 2.3, 1.3, 0.3] -> Predykcja: [0.998, 0.001, 0.001] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.4, 3.2, 1.3, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.5, 1.6, 0.6] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.8, 1.9, 0.4] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.8, 3.0, 1.4, 0.3] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.1, 3.8, 1.6, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [4.6, 3.2, 1.4, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.3, 3.7, 1.5, 0.2] -> Predykcja: [0.999, 0.0, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [5.0, 3.3, 1.4, 0.2] -> Predykcja: [0.999, 0.001, 0.0] -> Rzeczywista: [1.0, 0.0, 0.0]
# Wejście: [7.0, 3.2, 4.7, 1.4] -> Predykcja: [0.001, 0.969, 0.03] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.4, 3.2, 4.5, 1.5] -> Predykcja: [0.001, 0.941, 0.059] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.9, 3.1, 4.9, 1.5] -> Predykcja: [0.001, 0.927, 0.073] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.3, 4.0, 1.3] -> Predykcja: [0.0, 0.848, 0.151] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.5, 2.8, 4.6, 1.5] -> Predykcja: [0.0, 0.877, 0.122] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 2.8, 4.5, 1.3] -> Predykcja: [0.0, 0.845, 0.154] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.3, 3.3, 4.7, 1.6] -> Predykcja: [0.0, 0.838, 0.162] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [4.9, 2.4, 3.3, 1.0] -> Predykcja: [0.001, 0.971, 0.028] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.6, 2.9, 4.6, 1.3] -> Predykcja: [0.001, 0.962, 0.037] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.2, 2.7, 3.9, 1.4] -> Predykcja: [0.0, 0.828, 0.172] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.0, 2.0, 3.5, 1.0] -> Predykcja: [0.001, 0.956, 0.043] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.9, 3.0, 4.2, 1.5] -> Predykcja: [0.0, 0.902, 0.098] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.0, 2.2, 4.0, 1.0] -> Predykcja: [0.001, 0.971, 0.028] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.1, 2.9, 4.7, 1.4] -> Predykcja: [0.0, 0.831, 0.169] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 2.9, 3.6, 1.3] -> Predykcja: [0.001, 0.97, 0.029] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.7, 3.1, 4.4, 1.4] -> Predykcja: [0.001, 0.97, 0.029] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 3.0, 4.5, 1.5] -> Predykcja: [0.0, 0.659, 0.34] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.8, 2.7, 4.1, 1.0] -> Predykcja: [0.001, 0.973, 0.026] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.2, 2.2, 4.5, 1.5] -> Predykcja: [0.0, 0.222, 0.778] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 2.5, 3.9, 1.1] -> Predykcja: [0.001, 0.966, 0.033] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.9, 3.2, 4.8, 1.8] -> Predykcja: [0.0, 0.004, 0.996] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.1, 2.8, 4.0, 1.3] -> Predykcja: [0.001, 0.968, 0.031] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.3, 2.5, 4.9, 1.5] -> Predykcja: [0.0, 0.016, 0.984] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.1, 2.8, 4.7, 1.2] -> Predykcja: [0.001, 0.928, 0.071] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.4, 2.9, 4.3, 1.3] -> Predykcja: [0.001, 0.968, 0.031] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.6, 3.0, 4.4, 1.4] -> Predykcja: [0.001, 0.965, 0.034] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.8, 2.8, 4.8, 1.4] -> Predykcja: [0.001, 0.931, 0.069] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.7, 3.0, 5.0, 1.7] -> Predykcja: [0.0, 0.581, 0.419] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.0, 2.9, 4.5, 1.5] -> Predykcja: [0.0, 0.798, 0.202] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 2.6, 3.5, 1.0] -> Predykcja: [0.001, 0.976, 0.023] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.4, 3.8, 1.1] -> Predykcja: [0.001, 0.964, 0.035] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.4, 3.7, 1.0] -> Predykcja: [0.001, 0.972, 0.027] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.8, 2.7, 3.9, 1.2] -> Predykcja: [0.001, 0.968, 0.031] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.0, 2.7, 5.1, 1.6] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.4, 3.0, 4.5, 1.5] -> Predykcja: [0.0, 0.403, 0.597] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.0, 3.4, 4.5, 1.6] -> Predykcja: [0.0, 0.854, 0.145] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.7, 3.1, 4.7, 1.5] -> Predykcja: [0.001, 0.935, 0.065] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.3, 2.3, 4.4, 1.3] -> Predykcja: [0.001, 0.909, 0.091] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 3.0, 4.1, 1.3] -> Predykcja: [0.001, 0.949, 0.05] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.5, 4.0, 1.3] -> Predykcja: [0.0, 0.894, 0.106] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.5, 2.6, 4.4, 1.2] -> Predykcja: [0.0, 0.851, 0.149] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.1, 3.0, 4.6, 1.4] -> Predykcja: [0.0, 0.89, 0.11] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.8, 2.6, 4.0, 1.2] -> Predykcja: [0.001, 0.962, 0.037] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.0, 2.3, 3.3, 1.0] -> Predykcja: [0.001, 0.971, 0.028] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.6, 2.7, 4.2, 1.3] -> Predykcja: [0.0, 0.897, 0.103] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 3.0, 4.2, 1.2] -> Predykcja: [0.001, 0.962, 0.037] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 2.9, 4.2, 1.3] -> Predykcja: [0.001, 0.938, 0.061] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.2, 2.9, 4.3, 1.3] -> Predykcja: [0.001, 0.962, 0.037] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.1, 2.5, 3.0, 1.1] -> Predykcja: [0.002, 0.973, 0.025] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [5.7, 2.8, 4.1, 1.3] -> Predykcja: [0.001, 0.942, 0.057] -> Rzeczywista: [0.0, 1.0, 0.0]
# Wejście: [6.3, 3.3, 6.0, 2.5] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.8, 2.7, 5.1, 1.9] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.1, 3.0, 5.9, 2.1] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 2.9, 5.6, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.5, 3.0, 5.8, 2.2] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.6, 3.0, 6.6, 2.1] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [4.9, 2.5, 4.5, 1.7] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.3, 2.9, 6.3, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 2.5, 5.8, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.2, 3.6, 6.1, 2.5] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.5, 3.2, 5.1, 2.0] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 2.7, 5.3, 1.9] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.8, 3.0, 5.5, 2.1] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.7, 2.5, 5.0, 2.0] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.8, 2.8, 5.1, 2.4] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 3.2, 5.3, 2.3] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.5, 3.0, 5.5, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.7, 3.8, 6.7, 2.2] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.7, 2.6, 6.9, 2.3] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.0, 2.2, 5.0, 1.5] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.9, 3.2, 5.7, 2.3] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.6, 2.8, 4.9, 2.0] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.7, 2.8, 6.7, 2.0] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 2.7, 4.9, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 3.3, 5.7, 2.1] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.2, 3.2, 6.0, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.2, 2.8, 4.8, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.1, 3.0, 4.9, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 2.8, 5.6, 2.1] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.2, 3.0, 5.8, 1.6] -> Predykcja: [0.0, 0.003, 0.997] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.4, 2.8, 6.1, 1.9] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.9, 3.8, 6.4, 2.0] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 2.8, 5.6, 2.2] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 2.8, 5.1, 1.5] -> Predykcja: [0.0, 0.025, 0.975] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.1, 2.6, 5.6, 1.4] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [7.7, 3.0, 6.1, 2.3] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 3.4, 5.6, 2.4] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.4, 3.1, 5.5, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.0, 3.0, 4.8, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.9, 3.1, 5.4, 2.1] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 3.1, 5.6, 2.4] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.9, 3.1, 5.1, 2.3] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.8, 2.7, 5.1, 1.9] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.8, 3.2, 5.9, 2.3] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 3.3, 5.7, 2.5] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.7, 3.0, 5.2, 2.3] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.3, 2.5, 5.0, 1.9] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.5, 3.0, 5.2, 2.0] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [6.2, 3.4, 5.4, 2.3] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
# Wejście: [5.9, 3.0, 5.1, 1.8] -> Predykcja: [0.0, 0.001, 0.999] -> Rzeczywista: [0.0, 0.0, 1.0]
